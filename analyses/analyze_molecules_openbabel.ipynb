# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload

# %%
# %autoreload 2
from analyses.metrics import *

# %%
generated_paths = {
    "QM9": "/Users/ameyad/Documents/spherical-harmonic-net/others/qm9_xyz",
    "Symphony": "/Users/ameyad/Documents/spherical-harmonic-net/analyses/analysed_workdirs/qm9_bessel_embedding/nequip/interactions=3/l=5/position_channels=2/channels=64/global_embed=False/fait=1.0/pit=1.0/step=best/molecules",
    # "Symphony": "/Users/ameyad/Documents/spherical-harmonic-net/analyses/analysed_workdirs/qm9_7SEP/e3schnet_and_nequip/interactions=3/l=5/position_channels=2/channels=64/global_embed=False/fait=1.0/pit=1.0/step=best/molecules",
    "EDM": "/Users/ameyad/Documents/spherical-harmonic-net/others/edm/samples_edm_xyz",
    "GSchNet": "/Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules",
    "GSphereNet": "/Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules",
}

# %% [markdown]
# Corresponding molecules in OpenBabel:

# %%
all_generated_molecules_openbabel = {
    model: get_all_molecules_with_openbabel(path) for model, path in generated_paths.items()
}

valid_molecules_openbabel = {
    model: get_all_valid_molecules_with_openbabel(molecules) for model, molecules in all_generated_molecules_openbabel.items()
}
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127200.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125371.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025403.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129239.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_124735.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132157.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024047.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126644.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030998.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_004383.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132143.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_130967.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030973.log: Geometry 4])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030967.log: Geometry 6])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127599.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_000898.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_033063.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027016.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025167.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_020745.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125629.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030230.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024537.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132427.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127943.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_131847.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_045678.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127957.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125007.log: Geometry 6])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025013.log: Geometry 4])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030422.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_131728.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129173.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030436.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_003771.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_130393.log: Geometry 8])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126283.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030393.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_026297.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024480.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125577.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132023.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132989.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_133329.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024872.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_026917.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024873.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_128052.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126282.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_131926.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024481.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_026296.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129172.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127639.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030423.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_029172.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129166.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_004625.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127942.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129006.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132426.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126453.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126447.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027017.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025166.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027771.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126876.log: Geometry 10])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_130966.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126862.log: Geometry 6])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_029210.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129204.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_023729.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024046.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_026889.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129238.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_021116.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_133260.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127201.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025402.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_021114.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025414.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125366.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025400.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129206.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132140.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024044.log: Geometry 6])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_004419.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_126860.log: Geometry 7])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_021855.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132197.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025170.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_131677.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025164.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_033060.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027015.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_029038.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_032356.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132424.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027983.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025158.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132430.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_004627.log: Geometry 4])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127954.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_131844.log: Geometry 8])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127940.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125010.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_029158.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024468.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_124332.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129164.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125038.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_029170.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030421.log: Geometry 14])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_020632.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127820.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025945.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_021060.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027377.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_133302.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132034.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_005101.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_132949.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_023845.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_005100.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_032035.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_032021.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127362.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125575.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_125213.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_024482.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030391.log: Geometry 3])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_003773.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127809.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129165.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_020633.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030434.log: Geometry 14])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_129171.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_029159.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_131845.log: Geometry 4])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127941.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025830.log: Geometry 6])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_004626.log: Geometry 5])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_001038.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_030232.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025159.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_033049.log: Geometry 6])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_127996.log: Geometry 2])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_027982.log: Geometry 4])
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is [/home/surajit/SURE/Arghya/publish/Data/data_workflows-master-3c7a0808d1ac395ecf485adb2c1f59b1a61b30fc/qm9_g4mp2/tmp/extracted/output/dsgdb9nsd_025165.log: Geometry 5])
#
# ...
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=18_index=1240.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=563.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=16_index=943.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=12_index=98.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=11_index=47.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=16_index=360.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=14_index=418.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=14_index=381.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=370.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=14_index=168.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=166.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=16_index=573.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=22_index=464.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=22_index=470.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=589.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=17_index=964.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=19_index=479.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=399.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=617.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=14_index=99.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=17_index=553.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=20_index=1030.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=570.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=564.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=15_index=572.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=13_index=140.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gschnet/molecules/num_atoms=16_index=924.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules/num_atoms=15_index=46.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules/num_atoms=15_index=153.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules/num_atoms=18_index=246.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules/num_atoms=34_index=0.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules/num_atoms=13_index=278.xyz)
#
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is /Users/ameyad/Documents/spherical-harmonic-net/others/gspherenet/molecules/num_atoms=24_index=28.xyz)

# %% [markdown]
# Validity (OpenBabel):

# %%
# Make a dataframe for each model for the validity of the molecules.
validity_openbabel_df = pd.DataFrame(columns=["model", "validity"])

for model, molecules in valid_molecules_openbabel.items():
    validity_fraction = compute_validity(all_generated_molecules_openbabel[model], molecules)    
    validity_openbabel_df = pd.concat(
        [
            validity_openbabel_df,
            pd.DataFrame.from_records(
                {"model": model, "validity": [validity_fraction]}
            ),
        ],
        ignore_index=True,
    )

formatted_validity_df = validity_openbabel_df.transpose()
formatted_validity_df.columns = formatted_validity_df.iloc[0]
formatted_validity_df *= 100
formatted_validity_df = formatted_validity_df.drop("model")
formatted_validity_df = formatted_validity_df.astype(float)
formatted_validity_df = formatted_validity_df.round(2)
formatted_validity_df = formatted_validity_df.astype(str)
print(formatted_validity_df.style.to_latex())
# Out:
# \begin{tabular}{llllll}
# model & QM9 & Symphony & EDM & GSchNet & GSphereNet \\
# validity & 94.6 & 64.53 & 78.7 & 65.64 & 9.86 \\
# \end{tabular}
# /var/folders/rf/gl_bs24d2sg1ptcd__f19_pw0000gn/T/ipykernel_63957/63959593.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   validity_openbabel_df = pd.concat(

# %%
# Make a dataframe for each model for the uniqueness of the molecules.
uniqueness_openbabel_df = pd.DataFrame(columns=["model", "uniqueness"])

for model, molecules in valid_molecules_openbabel.items():
    uniqueness_fraction = compute_uniqueness_with_openbabel(molecules)    
    uniqueness_openbabel_df = pd.concat(
        [
            uniqueness_openbabel_df,
            pd.DataFrame.from_records(
                {"model": model, "uniqueness": [uniqueness_fraction]}
            ),
        ],
        ignore_index=True,
    )

formatted_uniqueness_df = uniqueness_openbabel_df.transpose()
formatted_uniqueness_df.columns = formatted_uniqueness_df.iloc[0]
formatted_uniqueness_df *= 100
formatted_uniqueness_df = formatted_uniqueness_df.drop("model")
formatted_uniqueness_df = formatted_uniqueness_df.astype(float)
formatted_uniqueness_df = formatted_uniqueness_df.round(2)
formatted_uniqueness_df = formatted_uniqueness_df.astype(str)
print(formatted_uniqueness_df.style.to_latex())
# Out:
# QM9: 99.97
# Symphony: 95.52
# EDM: 99.97
# GSchNet: 98.66
# GSphereNet: 7.51
# \begin{tabular}{llllll}
# model & QM9 & Symphony & EDM & GSchNet & GSphereNet \\
# uniqueness & 99.97 & 95.52 & 99.97 & 98.66 & 7.51 \\
# \end{tabular}
# /var/folders/rf/gl_bs24d2sg1ptcd__f19_pw0000gn/T/ipykernel_63957/3477337844.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   uniqueness_openbabel_df = pd.concat(
